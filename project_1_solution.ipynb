# %% [markdown]
# # Query 1.1
#
# Import the csv file of the stock of your choosing using 'pd.read_csv()' function into a dataframe. Shares of a company can be offered in more than one category. The category of a stock is indicated in the ‘Series’ column. If the csv file has data on more than one category, the ‘Date’ column will have repeating values. To avoid repetitions in the date, remove all the rows where 'Series' column is NOT 'EQ'. Analyze and understand each column properly. You'd find the head(), tail() and describe() functions to be immensely useful for exploration. You're free to carry out any other exploration of your own.

# %%
import pandas as pd
df = pd.read_csv('MINDTREE.csv')
df.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  MINDTREE     EQ  15-May-2017      510.60      507.35      515.00
# 1  MINDTREE     EQ  16-May-2017      509.45      507.00      515.85
# 2  MINDTREE     EQ  17-May-2017      511.30      507.05      519.70
# 3  MINDTREE     EQ  18-May-2017      506.35      502.00      516.75
# 4  MINDTREE     EQ  19-May-2017      492.90      491.95      502.95
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     505.90      510.50       509.45         510.39                 271952
# 1     506.00      511.00       511.30         512.69                 207011
# 2     502.75      504.00       506.35         512.10                 391401
# 3     486.00      487.50       492.90         505.60                 852336
# 4     489.50      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42

# %%
df.isna().head()
# Out:
#    Symbol  Series   Date  Prev Close  Open Price  High Price  Low Price  \
# 0   False   False  False       False       False       False      False
# 1   False   False  False       False       False       False      False
# 2   False   False  False       False       False       False      False
# 3   False   False  False       False       False       False      False
# 4   False   False  False       False       False       False      False
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  Turnover  \
# 0       False        False          False                  False     False
# 1       False        False          False                  False     False
# 2       False        False          False                  False     False
# 3       False        False          False                  False     False
# 4       False        False          False                  False     False
#
#    No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0          False            False                   False
# 1          False            False                   False
# 2          False            False                   False
# 3          False            False                   False
# 4          False            False                   False

# %%
df.isnull().head()
# Out:
#    Symbol  Series   Date  Prev Close  Open Price  High Price  Low Price  \
# 0   False   False  False       False       False       False      False
# 1   False   False  False       False       False       False      False
# 2   False   False  False       False       False       False      False
# 3   False   False  False       False       False       False      False
# 4   False   False  False       False       False       False      False
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  Turnover  \
# 0       False        False          False                  False     False
# 1       False        False          False                  False     False
# 2       False        False          False                  False     False
# 3       False        False          False                  False     False
# 4       False        False          False                  False     False
#
#    No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0          False            False                   False
# 1          False            False                   False
# 2          False            False                   False
# 3          False            False                   False
# 4          False            False                   False

# %%
filtered_data = df[df.Series=='EQ']
filtered_data.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  MINDTREE     EQ  15-May-2017      510.60      507.35      515.00
# 1  MINDTREE     EQ  16-May-2017      509.45      507.00      515.85
# 2  MINDTREE     EQ  17-May-2017      511.30      507.05      519.70
# 3  MINDTREE     EQ  18-May-2017      506.35      502.00      516.75
# 4  MINDTREE     EQ  19-May-2017      492.90      491.95      502.95
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     505.90      510.50       509.45         510.39                 271952
# 1     506.00      511.00       511.30         512.69                 207011
# 2     502.75      504.00       506.35         512.10                 391401
# 3     486.00      487.50       492.90         505.60                 852336
# 4     489.50      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 494 entries, 0 to 493
# Data columns (total 15 columns):
# Symbol                    494 non-null object
# Series                    494 non-null object
# Date                      494 non-null object
# Prev Close                494 non-null float64
# Open Price                494 non-null float64
# High Price                494 non-null float64
# Low Price                 494 non-null float64
# Last Price                494 non-null float64
# Close Price               494 non-null float64
# Average Price             494 non-null float64
# Total Traded Quantity     494 non-null int64
# Turnover                  494 non-null float64
# No. of Trades             494 non-null int64
# Deliverable Qty           494 non-null int64
# % Dly Qt to Traded Qty    494 non-null float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 56.0+ KB

# %%
filtered_data.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   494.000000   494.000000   494.000000   494.000000   494.000000
# mean    778.486032   779.720547   792.118421   767.127328   779.634919
# std     214.140514   214.851383   218.056333   210.381329   214.484986
# min     442.500000   443.000000   448.750000   439.050000   441.400000
# 25%     537.025000   537.975000   545.862500   528.012500   535.862500
# 50%     835.075000   838.000000   851.525000   820.625000   835.025000
# 75%     968.137500   968.500000   980.500000   949.450000   969.950000
# max    1161.950000  1165.000000  1183.800000  1147.800000  1166.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   494.000000     494.000000           4.940000e+02  4.940000e+02
# mean    779.434413     780.076619           1.388615e+06  1.191635e+09
# std     213.989087     214.038370           1.450169e+06  1.373025e+09
# min     442.500000     442.240000           4.630000e+04  2.305583e+07
# 25%     537.400000     537.410000           5.724762e+05  3.399893e+08
# 50%     835.875000     835.615000           1.006586e+06  8.580623e+08
# 75%     969.775000     967.802500           1.631997e+06  1.431053e+09
# max    1161.950000    1167.480000           1.338521e+07  1.298866e+10
#
#        No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# count     494.000000     4.940000e+02               494.00000
# mean    33021.139676     3.463618e+05                29.18668
# std     30613.616442     3.420743e+05                14.05687
# min      1502.000000     1.505300e+04                 5.87000
# 25%     14062.750000     1.523290e+05                18.69500
# 50%     25609.500000     2.529855e+05                26.39500
# 75%     42737.000000     4.366368e+05                37.06250
# max    311806.000000     3.851210e+06                91.89000

# %% [markdown]
# # Query 1.2
#
# Calculate the maximum, minimum and mean price for the last 90 days. (price=Closing Price unless stated otherwise)

# %%
filtered_data['Close Price'].tail(90).mean()
# Out:
# 918.61222222222227

# %%
filtered_data['Close Price'].tail(90).max()
# Out:
# 989.39999999999998

# %%
filtered_data['Close Price'].tail(90).min()
# Out:
# 812.25

# %% [markdown]
# # Query 1.3
#
# Analyse the data types for each column of the dataframe. Pandas knows how to deal with dates in an intelligent manner. But to make use of Pandas functionality for dates, you need to ensure that the column is of type 'datetime64(ns)'. Change the date column from 'object' type to 'datetime64(ns)' for future convenience. See what happens if you subtract the minimum value of the date column from the maximum value.

# %%
filtered_data.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  MINDTREE     EQ  15-May-2017      510.60      507.35      515.00
# 1  MINDTREE     EQ  16-May-2017      509.45      507.00      515.85
# 2  MINDTREE     EQ  17-May-2017      511.30      507.05      519.70
# 3  MINDTREE     EQ  18-May-2017      506.35      502.00      516.75
# 4  MINDTREE     EQ  19-May-2017      492.90      491.95      502.95
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     505.90      510.50       509.45         510.39                 271952
# 1     506.00      511.00       511.30         512.69                 207011
# 2     502.75      504.00       506.35         512.10                 391401
# 3     486.00      487.50       492.90         505.60                 852336
# 4     489.50      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42

# %%
filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])

# %%
import numpy as np
filtered_data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
filtered_data['Date'].max()-filtered_data['Date'].min()
# Out:
# Timedelta('728 days 00:00:00')

# %% [markdown]
# # Query 1.4
#
# In a separate array , calculate the monthwise VWAP (Volume Weighted Average Price ) of the stock. ( VWAP = sum(price*volume)/sum(volume) ) To know more about VWAP , visit - VWAP definition {Hint : Create a new dataframe column ‘Month’. The values for this column can be derived from the ‘Date” column by using appropriate pandas functions. Similarly, create a column ‘Year’ and initialize it. Then use the 'groupby()' function by month and year. Finally, calculate the vwap value for each month (i.e. for each group created).

# %%
filtered_data['Month'] = pd.DatetimeIndex(filtered_data['Date']).month
filtered_data['Year'] = pd.DatetimeIndex(filtered_data['Date']).year
filtered_data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42
#
#    Month  Year
# 0      5  2017
# 1      5  2017
# 2      5  2017
# 3      5  2017
# 4      5  2017

# %%
filtered_data.tail()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 489  MINDTREE     EQ 2019-05-07      981.75       982.8      985.00
# 490  MINDTREE     EQ 2019-05-08      979.95       981.0      985.00
# 491  MINDTREE     EQ 2019-05-09      980.50       979.6      983.15
# 492  MINDTREE     EQ 2019-05-10      980.45       980.4      982.90
# 493  MINDTREE     EQ 2019-05-13      975.35       973.4      983.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 489     975.00       981.0       979.95         979.77                1242934
# 490     971.05       982.0       980.50         979.84                4301316
# 491     976.10       980.9       980.45         980.02                3787159
# 492     973.00       974.0       975.35         977.55                 215170
# 493     970.30       981.0       979.10         980.16                 485941
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 489  1.217784e+09          10864           884988                   71.20
# 490  4.214603e+09          13038          3851210                   89.54
# 491  3.711482e+09           8159          3479880                   91.89
# 492  2.103396e+08           5128            26734                   12.42
# 493  4.762997e+08          14005           222691                   45.83
#
#      Month  Year
# 489      5  2019
# 490      5  2019
# 491      5  2019
# 492      5  2019
# 493      5  2019

# %%
filtered_data['VWAP'] = (filtered_data['Close Price'] * filtered_data['Total Traded Quantity']).cumsum() / filtered_data['Total Traded Quantity'].fillna(0).cumsum()
data_vwap = filtered_data[['Month','Year','VWAP']]
group = data_vwap.groupby(['Month','Year'])
group.first()
# Out:
#                   VWAP
# Month Year
# 1     2018  516.202743
#       2019  843.125130
# 2     2018  572.722380
#       2019  846.155182
# 3     2018  609.866603
#       2019  848.327396
# 4     2018  651.524063
#       2019  853.178143
# 5     2017  509.450000
#       2018  730.334478
#       2019  856.030810
# 6     2017  522.517683
#       2018  760.847401
# 7     2017  528.654830
#       2018  776.898919
# 8     2017  521.674873
#       2018  806.405595
# 9     2017  514.842649
#       2018  822.588413
# 10    2017  503.871258
#       2018  840.417469
# 11    2017  501.226909
#       2018  842.242954
# 12    2017  504.364596
#       2018  842.393059

# %%
data_vwap.head()
# Out:
#    Month  Year        VWAP
# 0      5  2017  509.450000
# 1      5  2017  510.249582
# 2      5  2017  508.495948
# 3      5  2017  500.779579
# 4      5  2017  500.222798

# %%
data_vwap.tail()
# Out:
#      Month  Year        VWAP
# 489      5  2019  856.636578
# 490      5  2019  857.418361
# 491      5  2019  858.098293
# 492      5  2019  858.135098
# 493      5  2019  858.220789

# %%
group = data_vwap.groupby(['Month','Year'])
group.first()
# Out:
#                   VWAP
# Month Year
# 1     2018  516.202743
#       2019  843.125130
# 2     2018  572.722380
#       2019  846.155182
# 3     2018  609.866603
#       2019  848.327396
# 4     2018  651.524063
#       2019  853.178143
# 5     2017  509.450000
#       2018  730.334478
#       2019  856.030810
# 6     2017  522.517683
#       2018  760.847401
# 7     2017  528.654830
#       2018  776.898919
# 8     2017  521.674873
#       2018  806.405595
# 9     2017  514.842649
#       2018  822.588413
# 10    2017  503.871258
#       2018  840.417469
# 11    2017  501.226909
#       2018  842.242954
# 12    2017  504.364596
#       2018  842.393059

# %% [markdown]
# # Query 1.5
#
# Write a function to calculate the average price over the last N days of the stock price data where N is a user defined parameter. Write a second function to calculate the profit/loss percentage over the last N days. Calculate the average price AND the profit/loss percentages over the course of last - 1 week, 2 weeks, 1 month, 3 months, 6 months and 1 year. {Note : Profit/Loss percentage between N days is the percentage change between the closing prices of the 2 days }

# %%
def avg_price(N):
    avg = filtered_data['Close Price'].tail(N).sum()/N
    return avg
avg_price(6) # last 5 days average price
# Out:
# 979.51666666666677

# %%
print("Average prices for last N days are as follows:")
print("Last 1 week",avg_price(5))
print("Last 2 weeks",avg_price(10))
print("Last 1 month",avg_price(20))
print("Last 3 months",avg_price(60))
print("Last 6 months",avg_price(120))
print("Last 1 year",avg_price(240))
# Out:
# Average prices for last N days are as follows:
# Last 1 week 979.07
# Last 2 weeks 978.58
# Last 1 month 977.4675
# Last 3 months 943.014166667
# Last 6 months 902.885416667
# Last 1 year 948.197083333

# %%
def prof_loss(N):
    difference = (filtered_data['Close Price'].tail(N).iloc[N-1] - filtered_data['Close Price'].tail(N).iloc[0])
    if difference >0:
        profit = difference
        profit_perc = (profit/filtered_data['Close Price'].tail(N).iloc[N-1])*100
        return profit_perc
    if difference < 0:
        loss = -difference
        loss_perc = (loss/filtered_data['Close Price'].tail(N).iloc[N-1])*100
        return loss_perc

# %%
prof_loss(10)
# Out:
# 0.33193749361658664

# %%
print("Loss/Profit percentage for last N days are as follows:")
print("Last 1 week",prof_loss(5))
print("Last 2 weeks",prof_loss(10))
print("Last 1 month",prof_loss(20))
print("Last 3 months",prof_loss(60))
print("Last 6 months",prof_loss(120))
print("Last 1 year",prof_loss(240))
# Out:
# Loss/Profit percentage for last N days are as follows:
# Last 1 week 0.0868144214074
# Last 2 weeks 0.331937493617
# Last 1 month 0.903891328771
# Last 3 months 6.23531814932
# Last 6 months 14.1660708814
# Last 1 year 4.06495761414

# %% [markdown]
# # Query 1.6
#
# Add a column 'Day_Perc_Change' where the values are the daily change in percentages i.e. the percentage change between 2 consecutive day's closing prices. Instead of using the basic mathematical formula for computing the same, use 'pct_change()' function provided by Pandas for dataframes. You will note that the first entry of the column will have a ‘Nan’ value. Why does this happen? Either remove the first row, or set the entry to 0 before proceeding.

# %%
filtered_data['Day_Perc_Change'] = filtered_data['Close Price'].pct_change()

# %%
filtered_data['Day_Perc_Change'].head()
# Out:
# 0         NaN
# 1    0.003631
# 2   -0.009681
# 3   -0.026563
# 4    0.009333
# Name: Day_Perc_Change, dtype: float64

# %%
filtered_data['Day_Perc_Change'].dropna()
# Out:
# 1      0.003631
# 2     -0.009681
# 3     -0.026563
# 4      0.009333
# 5      0.009749
# 6     -0.002389
# 7      0.017560
# 8      0.066575
# 9     -0.015996
# 10    -0.008688
# 11     0.012911
# 12     0.012188
# 13    -0.012042
# 14     0.004652
# 15     0.032506
# 16    -0.019284
# 17    -0.017926
# 18     0.012293
# 19    -0.008740
# 20     0.001949
# 21    -0.014820
# 22    -0.015983
# 23    -0.010415
# 24    -0.005600
# 25     0.001845
# 26     0.007463
# 27    -0.000289
# 28     0.002694
# 29     0.021113
# 30    -0.010056
#          ...
# 464   -0.007733
# 465   -0.002015
# 466    0.003453
# 467    0.000476
# 468    0.001799
# 469   -0.003011
# 470   -0.000318
# 471    0.010016
# 472    0.004565
# 473    0.005119
# 474    0.008366
# 475    0.006596
# 476   -0.001024
# 477    0.004100
# 478   -0.007350
# 479   -0.004062
# 480    0.007950
# 481   -0.000820
# 482    0.004101
# 483    0.010210
# 484   -0.013695
# 485    0.005534
# 486    0.000153
# 487   -0.011412
# 488    0.011905
# 489   -0.001833
# 490    0.000561
# 491   -0.000051
# 492   -0.005202
# 493    0.003845
# Name: Day_Perc_Change, Length: 493, dtype: float64

# %%
filtered_data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42
#
#    Month  Year        VWAP  Day_Perc_Change
# 0      5  2017  509.450000              NaN
# 1      5  2017  510.249582         0.003631
# 2      5  2017  508.495948        -0.009681
# 3      5  2017  500.779579        -0.026563
# 4      5  2017  500.222798         0.009333

# %%
filtered_data['Day_Perc_Change'] = filtered_data['Close Price'].pct_change().fillna(0)
filtered_data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42
#
#    Month  Year        VWAP  Day_Perc_Change
# 0      5  2017  509.450000         0.000000
# 1      5  2017  510.249582         0.003631
# 2      5  2017  508.495948        -0.009681
# 3      5  2017  500.779579        -0.026563
# 4      5  2017  500.222798         0.009333

# %% [markdown]
# # Query 1.7
#
# Add another column 'Trend' whose values are: 'Slight or No change' for 'Day_Perc_Change' in between -0.5 and 0.5 'Slight positive' for 'Day_Perc_Change' in between 0.5 and 1 'Slight negative' for 'Day_Perc_Change' in between -0.5 and -1 'Positive' for 'Day_Perc_Change' in between 1 and 3 'Negative' for 'Day_Perc_Change' in between -1 and -3 'Among top gainers' for 'Day_Perc_Change' in between 3 and 7 'Among top losers' for 'Day_Perc_Change' in between -3 and -7 'Bull run' for 'Day_Perc_Change' >7 'Bear drop' for 'Day_Perc_Change' <-7

# %%
if((filtered_data['Day_Perc_Change'] >= -0.5) & (filtered_data['Day_Perc_Change'] <= 0.5)).all():
    filtered_data['Trend'] = 'Slight or No change'
if((filtered_data['Day_Perc_Change'] >= 0.5) & (filtered_data['Day_Perc_Change'] <= 1)).all():
    filtered_data['Trend'] = 'Slight positive'
if((filtered_data['Day_Perc_Change'] >= -0.5) & (filtered_data['Day_Perc_Change'] <= -1)).all():
    filtered_data['Trend'] = 'Slight negative'
if((filtered_data['Day_Perc_Change'] >= 1) & (filtered_data['Day_Perc_Change'] <= 3)).all():
    filtered_data['Trend'] = 'Positive'       
if((filtered_data['Day_Perc_Change'] >= -1) & (filtered_data['Day_Perc_Change'] <= -3)).all():
    filtered_data['Trend'] ='Negative'
if((filtered_data['Day_Perc_Change'] >= 3) & (filtered_data['Day_Perc_Change'] <= 7)).all():
    filtered_data['Trend'] = 'Among top gainers'
if((filtered_data['Day_Perc_Change'] >= -3) & (filtered_data['Day_Perc_Change'] <= -7)).all():
    filtered_data['Trend'] =  'Among top losers'
if(filtered_data['Day_Perc_Change'] >7).all():
    filtered_data['Trend'] =  'Bull run'  
if(filtered_data['Day_Perc_Change'] < -7).all():
    filtered_data['Trend'] = 'Bear drop' 
filtered_data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42
#
#    Month  Year        VWAP  Day_Perc_Change                Trend
# 0      5  2017  509.450000         0.000000  Slight or No change
# 1      5  2017  510.249582         0.003631  Slight or No change
# 2      5  2017  508.495948        -0.009681  Slight or No change
# 3      5  2017  500.779579        -0.026563  Slight or No change
# 4      5  2017  500.222798         0.009333  Slight or No change

# %%
filtered_data.head()
# Out:
#      Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  MINDTREE     EQ 2017-05-15      510.60      507.35      515.00     505.90
# 1  MINDTREE     EQ 2017-05-16      509.45      507.00      515.85     506.00
# 2  MINDTREE     EQ 2017-05-17      511.30      507.05      519.70     502.75
# 3  MINDTREE     EQ 2017-05-18      506.35      502.00      516.75     486.00
# 4  MINDTREE     EQ 2017-05-19      492.90      491.95      502.95     489.50
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      510.50       509.45         510.39                 271952
# 1      511.00       511.30         512.69                 207011
# 2      504.00       506.35         512.10                 391401
# 3      487.50       492.90         505.60                 852336
# 4      495.15       497.50         496.43                 352273
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0  1.388005e+08           8261           100362                   36.90
# 1  1.061317e+08           5550            82090                   39.65
# 2  2.004375e+08          13341           150098                   38.35
# 3  4.309377e+08          18513           170919                   20.05
# 4  1.748782e+08           8326            57853                   16.42
#
#    Month  Year        VWAP  Day_Perc_Change                Trend
# 0      5  2017  509.450000         0.000000  Slight or No change
# 1      5  2017  510.249582         0.003631  Slight or No change
# 2      5  2017  508.495948        -0.009681  Slight or No change
# 3      5  2017  500.779579        -0.026563  Slight or No change
# 4      5  2017  500.222798         0.009333  Slight or No change

# %% [markdown]
# # Query 1.8
#
# Find the average and median values of the column 'Total Traded Quantity' for each of the types of 'Trend'. {Hint : use 'groupby()' on the 'Trend' column and then calculate the average and median values of the column 'Total Traded Quantity'}

# %%
filtered_data.groupby(filtered_data.Trend).mean()['Total Traded Quantity']
filtered_data.groupby(filtered_data.Trend).median()['Total Traded Quantity']
# Out:
# Trend
# Slight or No change    1006586.5
# Name: Total Traded Quantity, dtype: float64

# %% [markdown]
# # Query 1.9
#
# SAVE the dataframe with the additional columns computed as a csv file week2.csv. In Module 2, you are going to get familiar with matplotlib, the python module which is used to visualize data.

# %%
filtered_data.to_csv('week2.csv')

# %%
import pandas as pd
df2 = pd.read_csv('week2.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0    Symbol Series        Date  Prev Close  Open Price  \
# 0           0  MINDTREE     EQ  2017-05-15      510.60      507.35
# 1           1  MINDTREE     EQ  2017-05-16      509.45      507.00
# 2           2  MINDTREE     EQ  2017-05-17      511.30      507.05
# 3           3  MINDTREE     EQ  2017-05-18      506.35      502.00
# 4           4  MINDTREE     EQ  2017-05-19      492.90      491.95
#
#    High Price  Low Price  Last Price  Close Price         ...           \
# 0      515.00     505.90      510.50       509.45         ...
# 1      515.85     506.00      511.00       511.30         ...
# 2      519.70     502.75      504.00       506.35         ...
# 3      516.75     486.00      487.50       492.90         ...
# 4      502.95     489.50      495.15       497.50         ...
#
#    Total Traded Quantity      Turnover  No. of Trades  Deliverable Qty  \
# 0                 271952  1.388005e+08           8261           100362
# 1                 207011  1.061317e+08           5550            82090
# 2                 391401  2.004375e+08          13341           150098
# 3                 852336  4.309377e+08          18513           170919
# 4                 352273  1.748782e+08           8326            57853
#
#    % Dly Qt to Traded Qty  Month  Year        VWAP  Day_Perc_Change  \
# 0                   36.90      5  2017  509.450000         0.000000
# 1                   39.65      5  2017  510.249582         0.003631
# 2                   38.35      5  2017  508.495948        -0.009681
# 3                   20.05      5  2017  500.779579        -0.026563
# 4                   16.42      5  2017  500.222798         0.009333
#
#                  Trend
# 0  Slight or No change
# 1  Slight or No change
# 2  Slight or No change
# 3  Slight or No change
# 4  Slight or No change
#
# [5 rows x 21 columns]
